# %%
import pandas as pd

# %%
df = pd.read_csv("drinks.csv")
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
# Top 20 countries with most beer consumption per citizen
df.sort_values("beer_servings", ascending=False).head(20)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
# 135          Poland            343              215             56
# 188       Venezuela            333              100              3
# 81          Ireland            313              118            165
# 129           Palau            306               63             23
# 140         Romania            297              122            167
# 16          Belgium            295               84            212
# 130          Panama            285              104             18
# 160           Spain            284              157            112
# ...

# %%
# Top 20 countries with most wine consumption per citizen
df.sort_values("wine_servings", ascending=False).head(20)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 61              France            127              151            370
# 136           Portugal            194               67            339
# 3              Andorra            245              138            312
# 166        Switzerland            185              100            280
# 48             Denmark            224               81            278
# 156           Slovenia            270               51            276
# 99          Luxembourg            236              133            271
# 42             Croatia            230               87            254
# 83               Italy             85               42            237
# 55   Equatorial Guinea             92                0            233
# 6            Argentina            193               25            221
# 185            Uruguay            115               35            220
# ...

# %%
# Top 20 countries with most spirit consumption per citizen
df.sort_values("spirit_servings", ascending=False).head(20)
# Out:
#                           country  beer_servings  spirit_servings  \
# 68                        Grenada            199              438
# 15                        Belarus            142              373
# 73                          Haiti              1              326
# 141            Russian Federation            247              326
# 144                     St. Lucia            171              315
# 72                         Guyana             93              302
# 155                      Slovakia            196              293
# 50                       Dominica             52              286
# 169                      Thailand             99              258
# 40                   Cook Islands              0              254
# 25                       Bulgaria            231              252
# 87                     Kazakhstan            124              246
# 98                      Lithuania            343              244
# ...

# %%
# Countries with the most consumption of alcohol overall per citizen
df.sort_values("total_litres_of_pure_alcohol", ascending=False).head(20)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus            142              373             42
# 98            Lithuania            343              244             56
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 45       Czech Republic            361              170            134
# 61               France            127              151            370
# 141  Russian Federation            247              326             73
# 81              Ireland            313              118            165
# 155            Slovakia            196              293            116
# 99           Luxembourg            236              133            271
# 65              Germany            346              117            175
# 75              Hungary            234              215            185
# ...
